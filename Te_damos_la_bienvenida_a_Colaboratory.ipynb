# %% [markdown]
# <a href="https://colab.research.google.com/github/alejandroantoniogutierrez/4GeeksAcademy/blob/master/Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nueva sección

# %%
import numpy as np
